# %%
import pandas as pd

# %%
food = pd.read_csv("../datasets/food_subset.csv")
drug_aliases = pd.read_csv("../datasets/drug_aliases.csv")
food_aliases = pd.read_csv("../datasets/food_aliases.csv")
allergens = pd.read_csv("../datasets/food_ingredients_and_allergens.csv")
train = pd.read_csv("../datasets/food_drug_pairs_train.csv")
gold = pd.read_csv("../datasets/food_drug_pairs_gold.csv")
alternatives = pd.read_csv("../datasets/alternative_foods.csv")

print("Food:", food.shape)
print("Drug aliases:", drug_aliases.shape)
print("Food aliases:", food_aliases.shape)
print("Allergens:", allergens.shape)
print("Train:", train.shape)
print("Gold:", gold.shape)
print("Alternatives:", alternatives.shape)
# Out:
# Food: (766, 15)
# Drug aliases: (49, 3)
# Food aliases: (67, 3)
# Allergens: (399, 7)
# Train: (7152, 24)
# Gold: (224, 8)
# Alternatives: (197, 13)

# %%
print("Food columns:")
print(food.columns.tolist())

print("\nTrain columns:")
print(train.columns.tolist())

print("\nAllergen columns:")
print(allergens.columns.tolist())

print("\nAlternative columns:")
print(alternatives.columns.tolist())
# Out:
# Food columns:
# ['Food', 'energy', 'protein', 'fat', 'carbs', 'fiber', 'calcium', 'iron', 'vitamin_c', 'folate', 'vitamin_a', 'vitamin_e', 'is_alcohol', 'is_leafy_green', 'vitamin_k_proxy']
#
# Train columns:
# ['drug_index', 'drug_name', 'drug_contains', 'combined_text', 'Chemical_Class', 'Habit_Forming', 'Therapeutic_Class', 'Action_Class', 'food_name', 'energy', 'protein', 'fat', 'carbs', 'fiber', 'calcium', 'iron', 'vitamin_c', 'vitamin_a', 'vitamin_k_proxy', 'is_alcohol', 'is_leafy_green', 'meal_type', 'severity_silver', 'reason_tags_silver']
#
# Allergen columns:
# ['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil', 'Seasoning', 'Allergens', 'Prediction']
#
# Alternative columns:
# ['Food', 'food_type', 'consumption_type', 'energy', 'protein', 'carbs', 'fat', 'fiber', 'sugars', 'sodium', 'is_leafy_green', 'is_alcohol', 'quantity']
